# %%
import pickle

# %%
with open('phl_nbhd_coords.p', 'rb') as file:
    pnc = pickle.load(file)

# %%
with open('nyc_nbhd_coords.p', 'rb') as file:
    nnc = pickle.load(file)

# %%
nnc
# Out:
# {('New York', 'Annadale'): (-74.17340559792838, 40.53383634050007),
#  ('New York', 'Arden Heights'): (-74.1898534144778, 40.549740656386156),
#  ('New York', 'Arrochar'): (-74.07271538181718, 40.597155007445465),
#  ('New York', 'Arverne'): (-73.79897020060636, 40.59400551900006),
#  ('New York', 'Astoria'): (-73.91645214173312, 40.77059834050007),
#  ('New York', 'Astoria Heights'): (-73.89219977701372, 40.77197028700007),
#  ('New York', 'Auburndale'): (-73.79137914465628, 40.75094108512437),
#  ('New York', 'Bath Beach'): (-73.99473114336581, 40.595633661500074),
#  ('New York', 'Battery Park'): (-74.01654221482607, 40.711739491500055),
#  ('New York', 'Bay Ridge'): (-74.02927294271475, 40.63077132750004),
#  ('New York', 'Bay Terrace'): (-73.78131259722397, 40.786444171000056),
#  ('New York', 'Baychester'): (-73.84086823522199, 40.8713098931999),
#  ('New York', 'Bayside'): (-73.77069079889027, 40.76165259600006),
# ...
